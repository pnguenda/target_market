# %% [markdown]
# # This ML script would not have been possible without inspiration from, github user ***'wiamsuri'*** and their project ***'cnn-image-classifier-keras'***

# %%
from sklearn.datasets import load_files
from sklearn.model_selection import train_test_split
import numpy as np
from glob import glob
# from PIL import ImageFile
import random
from tqdm import tqdm
from keras.preprocessing import image
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from skimage.transform import resize
import os
import pandas as pd

# %% [markdown]
# # Load Images From File

# %%
image_names = [item.replace('resources/data_for_training_06/', '') for item in sorted(glob("resources/data_for_training_06/*/"))]
number_of_image_categories = len(image_names)
print('%d image categories.' % number_of_image_categories)
print('Three categories:')
print(image_names[:3])
# Out:
# 3 image categories.
# Three categories:
# ['brick_10/', 'siding_20/', 'unknown_00/']

# %%
def load_dataset(path):
    data = load_files(path)
    image_files = np.array(data['filenames'])
    image_targets = np_utils.to_categorical(np.array(data['target']), number_of_image_categories)
    return image_files, image_targets


image_files, image_targets = load_dataset('resources/data_for_training_06/')

trains_validate_files, test_files, trains_validate_targets, test_targets = \
    train_test_split(image_files, image_targets, test_size=0.2, random_state=42)

train_files, valid_files, train_targets, valid_targets = \
    train_test_split(trains_validate_files, trains_validate_targets, test_size=0.25, random_state=42)

image_names = [item for item in sorted(glob("resources/data_for_training_06/*/"))]

print('%s images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('%d training images.' % len(train_files))
print('%d validation images.' % len(valid_files))
print('%d test images.'% len(test_files))
# Out:
# 4105 images.
#
# 2463 training images.
# 821 validation images.
# 821 test images.

# %% [markdown]
# # Define function for preprocessing images

# %%
def path_to_tensor(img_path):

    img = image.load_img(img_path, grayscale=False, color_mode="rgb", target_size=(500, 500), interpolation="nearest")
    img_array = image.img_to_array(img)

    return np.expand_dims(img_array, axis=0)

def paths_to_tensor(img_paths):
    
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# # Preprocess images

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 2463/2463 [00:38<00:00, 63.92it/s]
# 100%|██████████| 821/821 [00:15<00:00, 52.17it/s]
# 100%|██████████| 821/821 [00:10<00:00, 82.01it/s]

# %% [markdown]
# # Build Model

# %%
model = Sequential()
# ADJUST FILTER?
model.add(Conv2D(filters=4, kernel_size=2, padding='same',
                 activation='relu', input_shape=(500, 500, 3)))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=8, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.1))

model.add(Conv2D(filters=12, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))



model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(3, activation='softmax'))


model.summary()

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 500, 500, 4)       52
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 250, 250, 4)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 250, 250, 8)       136
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 125, 125, 8)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 125, 125, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 12)      396
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 12)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 62, 62, 12)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 62, 62, 16)        784
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 31, 31, 16)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 31, 31, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 15376)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               3936512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 3,938,651
# Trainable params: 3,938,651
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model with training and validating images

# %%
epochs = 20

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.image_classifier.hdf5',
                               verbose=1, save_best_only=True)

history = model.fit(train_tensors, train_targets, validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=64, callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/20
# 39/39 [==============================] - ETA: 0s - loss: 1.6140 - accuracy: 0.4624
# Epoch 00001: val_loss improved from inf to 0.99881, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 192s 5s/step - loss: 1.6140 - accuracy: 0.4624 - val_loss: 0.9988 - val_accuracy: 0.5542
# Epoch 2/20
# 39/39 [==============================] - ETA: 0s - loss: 0.9424 - accuracy: 0.5367
# Epoch 00002: val_loss improved from 0.99881 to 0.94132, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 197s 5s/step - loss: 0.9424 - accuracy: 0.5367 - val_loss: 0.9413 - val_accuracy: 0.5956
# Epoch 3/20
# 39/39 [==============================] - ETA: 0s - loss: 0.8547 - accuracy: 0.6033
# Epoch 00003: val_loss improved from 0.94132 to 0.92221, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 203s 5s/step - loss: 0.8547 - accuracy: 0.6033 - val_loss: 0.9222 - val_accuracy: 0.6054
# Epoch 4/20
# 39/39 [==============================] - ETA: 0s - loss: 0.8170 - accuracy: 0.6411
# Epoch 00004: val_loss improved from 0.92221 to 0.88029, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 201s 5s/step - loss: 0.8170 - accuracy: 0.6411 - val_loss: 0.8803 - val_accuracy: 0.6638
# Epoch 5/20
# 39/39 [==============================] - ETA: 0s - loss: 0.7540 - accuracy: 0.6752
# Epoch 00005: val_loss improved from 0.88029 to 0.84383, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 201s 5s/step - loss: 0.7540 - accuracy: 0.6752 - val_loss: 0.8438 - val_accuracy: 0.6955
# Epoch 6/20
# 39/39 [==============================] - ETA: 0s - loss: 0.6899 - accuracy: 0.7138
# Epoch 00006: val_loss improved from 0.84383 to 0.74936, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 204s 5s/step - loss: 0.6899 - accuracy: 0.7138 - val_loss: 0.7494 - val_accuracy: 0.7125
# Epoch 7/20
# 39/39 [==============================] - ETA: 0s - loss: 0.6526 - accuracy: 0.7304
# Epoch 00007: val_loss did not improve from 0.74936
# 39/39 [==============================] - 195s 5s/step - loss: 0.6526 - accuracy: 0.7304 - val_loss: 0.8184 - val_accuracy: 0.6614
# Epoch 8/20
# 39/39 [==============================] - ETA: 0s - loss: 0.6106 - accuracy: 0.7479
# Epoch 00008: val_loss improved from 0.74936 to 0.71378, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 198s 5s/step - loss: 0.6106 - accuracy: 0.7479 - val_loss: 0.7138 - val_accuracy: 0.7259
# Epoch 9/20
# 39/39 [==============================] - ETA: 0s - loss: 0.5458 - accuracy: 0.7641
# Epoch 00009: val_loss did not improve from 0.71378
# 39/39 [==============================] - 209s 5s/step - loss: 0.5458 - accuracy: 0.7641 - val_loss: 0.7189 - val_accuracy: 0.7089
# Epoch 10/20
# 39/39 [==============================] - ETA: 0s - loss: 0.5061 - accuracy: 0.8015
# Epoch 00010: val_loss improved from 0.71378 to 0.68169, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 197s 5s/step - loss: 0.5061 - accuracy: 0.8015 - val_loss: 0.6817 - val_accuracy: 0.7333
# Epoch 11/20
# 39/39 [==============================] - ETA: 0s - loss: 0.4651 - accuracy: 0.8002
# Epoch 00011: val_loss improved from 0.68169 to 0.60189, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 197s 5s/step - loss: 0.4651 - accuracy: 0.8002 - val_loss: 0.6019 - val_accuracy: 0.7418
# Epoch 12/20
# 39/39 [==============================] - ETA: 0s - loss: 0.4145 - accuracy: 0.8295
# Epoch 00012: val_loss improved from 0.60189 to 0.58462, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 203s 5s/step - loss: 0.4145 - accuracy: 0.8295 - val_loss: 0.5846 - val_accuracy: 0.7674
# Epoch 13/20
# 39/39 [==============================] - ETA: 0s - loss: 0.3776 - accuracy: 0.8433
# Epoch 00013: val_loss improved from 0.58462 to 0.55612, saving model to saved_models/weights.best.image_classifier.hdf5
# 39/39 [==============================] - 202s 5s/step - loss: 0.3776 - accuracy: 0.8433 - val_loss: 0.5561 - val_accuracy: 0.7674
# Epoch 14/20
# 39/39 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.8587
# Epoch 00014: val_loss did not improve from 0.55612
# 39/39 [==============================] - 205s 5s/step - loss: 0.3403 - accuracy: 0.8587 - val_loss: 0.6175 - val_accuracy: 0.7442
# Epoch 15/20
# 39/39 [==============================] - ETA: 0s - loss: 0.3103 - accuracy: 0.8835
# Epoch 00015: val_loss did not improve from 0.55612
# 39/39 [==============================] - 204s 5s/step - loss: 0.3103 - accuracy: 0.8835 - val_loss: 0.5759 - val_accuracy: 0.7552
# Epoch 16/20
# 39/39 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.8847
# Epoch 00016: val_loss did not improve from 0.55612
# 39/39 [==============================] - 200s 5s/step - loss: 0.2758 - accuracy: 0.8847 - val_loss: 0.6011 - val_accuracy: 0.7649
# Epoch 17/20
# 39/39 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.8989
# Epoch 00017: val_loss did not improve from 0.55612
# 39/39 [==============================] - 198s 5s/step - loss: 0.2536 - accuracy: 0.8989 - val_loss: 0.5562 - val_accuracy: 0.7710
# Epoch 18/20
# 39/39 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9176
# Epoch 00018: val_loss did not improve from 0.55612
# 39/39 [==============================] - 198s 5s/step - loss: 0.2172 - accuracy: 0.9176 - val_loss: 0.6829 - val_accuracy: 0.7406
# Epoch 19/20
# 39/39 [==============================] - ETA: 0s - loss: 0.1884 - accuracy: 0.9306
# Epoch 00019: val_loss did not improve from 0.55612
# 39/39 [==============================] - 207s 5s/step - loss: 0.1884 - accuracy: 0.9306 - val_loss: 0.5969 - val_accuracy: 0.7783
# Epoch 20/20
# 39/39 [==============================] - ETA: 0s - loss: 0.1954 - accuracy: 0.9241
# Epoch 00020: val_loss did not improve from 0.55612
# 39/39 [==============================] - 192s 5s/step - loss: 0.1954 - accuracy: 0.9241 - val_loss: 0.6106 - val_accuracy: 0.7613

# %%
import pickle
# OPTIONAL WRITE HISTORY TO JSON
with open('trainHistoryDict', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

# %%
#READ in SAVED HISTORY
history = history = pickle.load(open('trainHistoryDict', "rb"))

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model

# %%
model = tf.keras.models.load_model('saved_models/weights.best.image_classifier.hdf5')

# %%
# model.load_weights('saved_models/weights.best.image_classifier.hdf5')
# model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

test_accuracy = 100*np.sum(np.array(predictions)==np.argmax(test_targets, axis=1))/len(predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 78.1973%

# %%
#Visualize the model's accuracy
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['training data', 'validation data'], loc='upper left')
plt.show()

# %%
for image in os.listdir('test_imgs'):
    img = plt.imread('test_imgs' + '/' + image)
    resized_image = resize(img, (500,500,3))
    predictions = model.predict(np.array([resized_image]))
#     print(f'{image}:\t {predictions}')
    if image.split("_")[0] == "brick":
        print(image, predictions)
#         print(f'{image}:\t {round(100 * predictions[0][0])}%')

# for image in os.listdir('test_imgs'):
#     img = plt.imread('test_imgs' + '/' + image)
#     resized_image = resize(img, (400,400,3))
#     predictions = model.predict(np.array([resized_image]))
# #     print(f'{image}:\t {predictions}')
#     if image.split("_")[0] == "brick":
# #         print(f'{image}:\t {round(100 * predictions[0][0])}%')

# for image in os.listdir('test_imgs'):
#     img = plt.imread('test_imgs' + '/' + image)
#     resized_image = resize(img, (400,400,3))
#     predictions = model.predict(np.array([resized_image]))
# #     print(f'{image}:\t {predictions}')
#     if image.split("_")[0] == "unknown":
# #         print(f'{image}:\t {round(100 * predictions[0][0])}%')

#['brick_10/', 'siding_20/', 'unknown_00/']
# Out:
# brick_7266.jpg [[0.57276136 0.19291398 0.23432463]]
# brick_81.jpg [[0.4792229  0.30561993 0.21515715]]
# brick_7664.jpg [[0.38837716 0.307335   0.3042878 ]]
# brick_5902.jpg [[0.2639096  0.5761641  0.15992628]]
# brick_5901.jpg [[0.1931238  0.25320718 0.553669  ]]
# brick_62.jpg [[0.8308647  0.09156745 0.07756779]]
# brick_7839.jpg [[0.42066547 0.2003674  0.37896714]]
# brick_6449.jpg [[0.28280202 0.3628855  0.35431245]]

# %%
new_image = plt.imread('test_imgs/brick_5901.jpg')
img = plt.imshow(new_image)

# %%
#Sort the predictions from least to greatest
list_index = [0, 1, 2]
x = predictions

for i in range(3):
  for j in range(3):
    if x[0][list_index[i]] > x[0][list_index[j]]:
      temp = list_index[i]
      list_index[i] = list_index[j]
      list_index[j] = temp

#Show the sorted labels in order
print(list_index)

# %%
# Plot history: 
plt.plot(history['loss'], label='(training data)')
plt.plot(history['val_loss'], label='(validation data)')
plt.title('Loss')
plt.ylabel('value')
plt.xlabel('No. epoch')
plt.legend(loc="upper right")
plt.show()
